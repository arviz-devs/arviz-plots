# %% [markdown]
# # Intro to PlotCollection

# %%
from importlib import import_module

import numpy as np
import xarray as xr
import matplotlib.pyplot as plt
from matplotlib.colors import to_hex
from bokeh.plotting import output_notebook, show

import arviz as az
from arviz_base import load_arviz_data
import arviz_plots as azp

# %%
output_notebook()
# Out:
# <style>
#         .bk-notebook-logo {
#             display: block;
#             width: 20px;
#             height: 20px;
#             background-image: url(data:image/png;base64,...);
#         }
#     </style>
#     <div>
#         <a href="https://bokeh.org" target="_blank" class="bk-notebook-logo"></a>
#         <span id="eefe42ef-ed55-489c-a578-b7c06cd6762b">Loading BokehJS ...</span>
#     </div>

# %%
xr.set_options(display_expand_data=False);
azp.style.use("arviz-clean")

# %%
idata = load_arviz_data("rugby")
post = idata.posterior.ds

# %%
def kde_artist(values, target, **kwargs):
    backend = kwargs.pop("backend")
    plot_backend = import_module(f"arviz_plots.backend.{backend}")
    grid, pdf = az.kde(np.array(values).flatten())
    return plot_backend.line(grid, pdf, target, **kwargs)

# %%
pc = azp.PlotCollection.wrap(
    post[["atts", "defs"]], 
    cols=["team"],
    col_wrap=3,
    plot_grid_kws={"figsize": (10, 4)}
)
pc.map(kde_artist, "kde")

# %%
pc = azp.PlotCollection.wrap(
    post[["atts", "defs"]], 
    cols=["team"],
    col_wrap=3,
    aes={"color": ["__variable__"]}, 
    color=[to_hex(f"C{i}") for i in range(2)],
    plot_grid_kws={"width":350, "height":200},
    backend="bokeh",
)
pc.map(kde_artist, "kde")
show(pc.viz["chart"].item())
# Out:
#   <div id="e02af672-601a-47e9-b35d-ea5fa4e32c00" data-root-id="p1176" style="display: contents;"></div>

# %%
from arviz_plots.plot_collection import _process_facet_dims

_process_facet_dims(post[["atts", "defs"]], ["__variable__"])
# Out:
# (2, {'atts': 1, 'defs': 1})

# %%
from arviz_plots.plot_collection import _process_facet_dims

_process_facet_dims(post[["atts", "defs"]], ["chain"])
# Out:
# (4, {})

# %%
pc.aes
# Out:
# DataTree('None', parent=None)
# ├── DataTree('atts')
# │       Dimensions:  ()
# │       Data variables:
# │           color    <U7 '#1a6587'
# └── DataTree('defs')
#         Dimensions:  ()
#         Data variables:
#             color    <U7 '#1a6587'

# %%
pc = azp.PlotCollection.grid(
    post[["atts", "defs"]], 
    cols=["team"],
    rows=["chain"], 
    plot_grid_kws={"figsize": (10, 6)}
)
pc.map(kde_artist, "kde")

# %%
pc = azp.PlotCollection.grid(
    post[["atts", "defs"]], 
    cols=["__variable__"],
    rows=["team"], 
    plot_grid_kws={"figsize": (8, 6)}
)
pc.map(kde_artist, "kde")

# %%
def title_artist(values, target, var_name, sel, isel, labeller_fun, **kwargs):
    backend = kwargs.pop("backend")
    plot_backend = import_module(f"arviz_plots.backend.{backend}")
    label = labeller_fun(var_name, sel, isel)
    return plot_backend.title(label, target, **kwargs)

pc = azp.PlotCollection.wrap(
    post[["atts", "defs", "home", "intercept"]], 
    cols=["__variable__", "team"],
    col_wrap=3,
    aes={"color": ["chain"]}, 
    color=[f"C{i}" for i in range(4)],
    plot_grid_kws={"figsize": (12, 6)},
)
pc.map(kde_artist, "kde")
# add title to help visualize what is happening
pc.map(title_artist, "title", subset_info=True, labeller_fun=az.labels.BaseLabeller().make_label_vert, ignore_aes={"color"})

# %%
pc = azp.PlotCollection.wrap(
    post[["atts", "defs", "home", "intercept"]], 
    cols=["__variable__", "team"],
    col_wrap=3,
    aes={"color": ["chain"]}, 
    color=[to_hex(f"C{i}") for i in range(4)],
    plot_grid_kws={"width":350, "height":200},
    backend="bokeh",
)
pc.map(kde_artist, "kde")
# add title to help visualize what is happening
pc.map(title_artist, "title", subset_info=True, labeller_fun=az.labels.BaseLabeller().make_label_vert, ignore_aes={"color"})
show(pc.viz["chart"].item())
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 10
#       1 pc = azp.PlotCollection.wrap(
#       2     post[["atts", "defs", "home", "intercept"]],
#       3     cols=["__variable__", "team"],
#    (...)
#       8     backend="bokeh",
#       9 )
# ---> 10 pc.map(kde_artist, "kde")
#      11 # add title to help visualize what is happening
#      12 pc.map(title_artist, "title", subset_info=True, labeller_fun=az.labels.BaseLabeller().make_label_vert, ignore_aes={"color"})
#
# File ~/proyectos/00_BM/arviz-devs/arviz-plots/src/arviz_plots/plot_collection.py:471, in PlotCollection.map(self, fun, fun_label, data, coords, ignore_aes, subset_info, store_artist, artist_dims, **kwargs)
#     469 if subset_info:
#     470     fun_kwargs = {**fun_kwargs, "var_name": var_name, "sel": sel, "isel": isel}
# --> 471 aux_artist = fun(da, target=target, **fun_kwargs)
#     472 if store_artist:
#     473     self.viz[var_name][fun_label].loc[sel] = aux_artist
#
# Cell In[5], line 5, in kde_artist(values, target, **kwargs)
#       3 plot_backend = import_module(f"arviz_plots.backend.{backend}")
#       4 grid, pdf = az.kde(np.array(values).flatten())
# ----> 5 return plot_backend.line(grid, pdf, target, **kwargs)
#
# File ~/proyectos/00_BM/arviz-devs/arviz-plots/src/arviz_plots/backend/bokeh/__init__.py:98, in line(x, y, target, color, alpha, width, linestyle, **artist_kws)
#      96 """Interface to bokeh for a line plot."""
#      97 kwargs = {"color": color, "alpha": alpha, "line_width": width, "line_dash": linestyle}
# ---> 98 return target.line(np.atleast_1d(x), np.atleast_1d(y), **_filter_kwargs(kwargs, artist_kws))
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/plotting/_decorators.py:87, in glyph_method.<locals>.decorator.<locals>.wrapped(self, *args, **kwargs)
#      85 if self.coordinates is not None:
#      86     kwargs.setdefault("coordinates", self.coordinates)
# ---> 87 return create_renderer(glyphclass, self.plot, **kwargs)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/plotting/_renderer.py:113, in create_renderer(glyphclass, plot, **kwargs)
#     110 # handle the mute glyph, we always set one
#     111 muted_visuals = pop_visuals(glyphclass, kwargs, prefix='muted_', defaults=glyph_visuals, override_defaults={'alpha':0.2})
# --> 113 glyph = make_glyph(glyphclass, kwargs, glyph_visuals)
#     114 nonselection_glyph = make_glyph(glyphclass, kwargs, nonselection_visuals)
#     115 selection_glyph = make_glyph(glyphclass, kwargs, selection_visuals)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/plotting/_renderer.py:142, in make_glyph(glyphclass, kws, extra)
#     140 kws = kws.copy()
#     141 kws.update(extra)
# --> 142 return glyphclass(**kws)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/models/glyphs.py:952, in Line.__init__(self, *args, **kwargs)
#     951 def __init__(self, *args, **kwargs) -> None:
# --> 952     super().__init__(*args, **kwargs)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/models/glyph.py:91, in ConnectedXYGlyph.__init__(self, *args, **kwargs)
#      90 def __init__(self, *args, **kwargs) -> None:
# ---> 91     super().__init__(*args, **kwargs)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/models/glyph.py:80, in XYGlyph.__init__(self, *args, **kwargs)
#      79 def __init__(self, *args, **kwargs) -> None:
# ---> 80     super().__init__(*args, **kwargs)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/models/glyph.py:101, in LineGlyph.__init__(self, *args, **kwargs)
#     100 def __init__(self, *args, **kwargs) -> None:
# --> 101     super().__init__(*args, **kwargs)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/models/glyph.py:58, in Glyph.__init__(self, *args, **kwargs)
#      57 def __init__(self, *args, **kwargs) -> None:
# ---> 58     super().__init__(*args, **kwargs)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/model/model.py:110, in Model.__init__(self, *args, **kwargs)
#     107 if "id" in kwargs:
#     108     raise ValueError("initializing 'id' is not allowed")
# --> 110 super().__init__(**kwargs)
#     111 default_theme.apply_to_model(self)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/core/has_props.py:295, in HasProps.__init__(self, **properties)
#     293     if value is Undefined or value is Intrinsic:
#     294         continue
# --> 295     setattr(self, name, value)
#     297 initialized = set(properties.keys())
#     298 for name in self.properties(_with_props=True): # avoid set[] for deterministic behavior
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/core/has_props.py:327, in HasProps.__setattr__(self, name, value)
#     325 properties = self.properties(_with_props=True)
#     326 if name in properties:
# --> 327     return super().__setattr__(name, value)
#     329 descriptor = getattr(self.__class__, name, None)
#     330 if isinstance(descriptor, property): # Python property
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/core/property/descriptors.py:332, in PropertyDescriptor.__set__(self, obj, value, setter)
#     329     class_name = obj.__class__.__name__
#     330     raise RuntimeError(f"{class_name}.{self.name} is a readonly property")
# --> 332 value = self.property.prepare_value(obj, self.name, value)
#     333 old = self._get(obj)
#     334 self._set(obj, old, value, setter=setter)
#
# File ~/anaconda3/envs/aplots/lib/python3.11/site-packages/bokeh/core/property/bases.py:364, in Property.prepare_value(self, owner, name, value, hint)
#     362 else:
#     363     obj_repr = owner if isinstance(owner, HasProps) else owner.__name__
# --> 364     raise ValueError(f"failed to validate {obj_repr}.{name}: {error}")
#     366 if isinstance(owner, HasProps):
#     367     obj = owner
#
# ValueError: failed to validate Line(id='p2745', ...).line_width: expected a value of type Real, got None of type NoneType
